# %% [markdown]
# <a href="https://colab.research.google.com/github/harisfariyano/algoritma-dan-struktur-data/blob/main/modul4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('=======operator arimatika=======')

#menggunakan oprator penjumlahan
a=1000 #type_data_integer
b=2000 #type_data_integer

c=a+b
print('hasil', a, "+", b, "=", c)

#menggunakan operator pengurangan
a=1000
b=2000

c=a-b
print('hasil', a, "-", b, "=", c)

#menggunakan operator perkalian
a=1000
b=2000

c=a*b
print('hasil', a, "*", b, "=", c)

#menggunakan operator pembagian
a=1000
b=2000

c=a/b
print('hasil', a, "/", b, "=", c)

#menggunakan operator sisa bagi
a=1000
b=2000

c=a%b
print('hasil', a, "%", b, "=", c)

#menggunakan operator pemangkatan
a=1000
b=2000

c=a**b
print('hasil', a, "**", b, "=", c)
# Out:
# =======operator arimatika=======
# hasil 1000 + 2000 = 3000
# hasil 1000 - 2000 = -1000
# hasil 1000 * 2000 = 2000000
# hasil 1000 / 2000 = 0.5
# hasil 1000 % 2000 = 1000
# hasil 1000 ** 2000 = ...

# %%
print('=======operator penugasan=======')

#operator pengisian
a=100
print(a)
a=25
print(a)

#operator penjumlahan
a=100
print(a)
a+=25
print(a)

#operator pengurangan 
a=100
print(a)
a-=25
print(a)

#operator pengkalian
a=100
print(a)
a/=25
print(a)

#operatoe pembagian
a=100
print(a)
a*=25
print(a)

#operator sisa bagi
a=100
print(a)
a%=25
print(a)

#operator pemangkatan
a=100
print(a)
a**=25
print(a)
# Out:
# =======operator penugasan=======
# 100
# 25
# 100
# 125
# 100
# 75
# 100
# 4.0
# 100
# 2500
# 100
# 0
# 100
# 100000000000000000000000000000000000000000000000000

# %%
print('==========Operator pembanding==========')

#Operator lebih besar
a=20
b=10

c=a>b
print('apakah a lebih besar dari b:',c)

#Operator lebih kecil
a=20
b=10

c=a<b
print('apakah a lebih kecil dari b:',c)

#operator sama dengan
a=20
b=10

c=a==b
print('apakah a samadengan b:',c)

#operator tidak sama dengan
a=20
b=10

c=a!=b
print('apakah a tidak sama dengan b:',c)
#operator lebih besar sama dengan
a=20
b=10

c=a>=b
print('apakah a lebih besar sama dengan b:',c)
#operator lebih kecil sama dengan
a=20
b=10

c=a<=b
print('apakah a lebih kecil sama dengan b:',c)
# Out:
# ==========Operator pembanding==========
# apakah a lebih besar dari b: True
# apakah a lebih kecil dari b: False
# apakah a samadengan b: False
# apakah a tidak sama dengan b: True
# apakah a lebih besar sama dengan b: True
# apakah a lebih kecil sama dengan b: False

# %%
print('==========Operator logika==========')

#logika AND
a = True
b = False

c = a and b
print(c)

#logika OR
a = True
b = False

c = a or b
print(c)

#logika not
a = True
b = False
c = not a, not b,
print(c)
# Out:
# ==========Operator logika==========
# False
# True
# (True, False)
# Hasil dari not True  : False
# Hasil dari not False : True

# %%
print('==================Data Bayi==================')
A =input('Nama bayi:')
B =int(input('Berat bayi dalam Kg adalah:'))
D =B*10
print('Berat bayi dalam Ons adalah:',D)
E =D+30
print('Berat',A,'satu bulan kedepan adalah',E,'Ons')
# Out:
# ==================Data Bayi==================
# Nama bayi:neysa
# Berat bayi dalam Kg adalah:2
# Berat bayi dalam Ons adalah: 20
# Berat neysa satu bulan kedepan adalah 50 Ons
